# %%
# Ставим необходимые пакеты
# !pip install catboost #Пакет градиентного бустинга от Яндекса. Использован в качестве базовой модели
# !pip install ipywidgets # этот и следующий нужны для нормального отображения гарфики в Colab
# !jupyter nbextension enable --py widgetsnbextension

# !pip install sweetviz #Крутой пакет анализа Датасета в одну строчку кода
#!pip install -U geometric-smote #пробуем балансировать cv_dataset
# !pip install shap #Пакет интерпритации весов модели для определения значимости признаков
#!pip install smogn # Аугментация для несбалансированных датасетов у меня не заработала
#!pip install git+https://github.com/nickkunz/smogn.git
# !git clone --recursive https://github.com/convergence-lab/SMOGN.git
# Out:
# Collecting catboost
#   Downloading catboost-1.2.1-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.10.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.1
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (7.7.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (3.6.5)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (3.0.8)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.3.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (67.7.2)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets)
#   Downloading jedi-0.19.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 32.5 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets) (4.8.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets) (6.5.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.1.2)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.3.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.9.2)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.7)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.6)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.10.0)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.2.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.1.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.8.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (23.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.18.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.19.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.1->jupyter-client->ipykernel>=4.5.1->ipywidgets) (1.16.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.9.2)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.6.2)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.4.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.1.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.21)
# Installing collected packages: jedi
# Successfully installed jedi-0.19.0
# Enabling notebook extension jupyter-js-widgets/extension...
# Paths used for configuration of notebook:
#     	/root/.jupyter/nbconfig/notebook.json
# Paths used for configuration of notebook:
#
#       - Validating: OK
# Paths used for configuration of notebook:
#     	/root/.jupyter/nbconfig/notebook.json
# Collecting sweetviz
#   Downloading sweetviz-2.2.1-py3-none-any.whl (15.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 97.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in /usr/local/lib/python3.10/dist-packages (from sweetviz) (1.5.3)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from sweetviz) (1.23.5)
# Requirement already satisfied: matplotlib>=3.1.3 in /usr/local/lib/python3.10/dist-packages (from sweetviz) (3.7.1)
# Requirement already satisfied: tqdm>=4.43.0 in /usr/local/lib/python3.10/dist-packages (from sweetviz) (4.66.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from sweetviz) (1.10.1)
# Requirement already satisfied: jinja2>=2.11.1 in /usr/local/lib/python3.10/dist-packages (from sweetviz) (3.1.2)
# Requirement already satisfied: importlib-resources>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from sweetviz) (6.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.11.1->sweetviz) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.3->sweetviz) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.3->sweetviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.3->sweetviz) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.3->sweetviz) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.3->sweetviz) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.3->sweetviz) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.3->sweetviz) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.3->sweetviz) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.16.0)
# Installing collected packages: sweetviz
# Successfully installed sweetviz-2.2.1
# Collecting shap
#   Downloading shap-0.42.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (547 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.9/547.9 kB 14.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (1.5.3)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.66.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (23.1)
# Collecting slicer==0.0.7 (from shap)
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.56.4)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba->shap) (67.7.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.42.1 slicer-0.0.7
# Cloning into 'SMOGN'...
# remote: Enumerating objects: 230, done.
# remote: Counting objects: 100% (230/230), done.
# remote: Compressing objects: 100% (169/169), done.
# remote: Total 230 (delta 106), reused 173 (delta 56), pack-reused 0
# Receiving objects: 100% (230/230), 5.69 MiB | 35.11 MiB/s, done.
# Resolving deltas: 100% (106/106), done.
# Submodule 'Imbalanced-Regression-DataSets' (https://github.com/paobranco/Imbalanced-Regression-DataSets.git) registered for path 'Imbalanced-Regression-DataSets'
# Cloning into '/content/SMOGN/Imbalanced-Regression-DataSets'...
# remote: Enumerating objects: 274, done.
# remote: Total 274 (delta 0), reused 0 (delta 0), pack-reused 274
# Receiving objects: 100% (274/274), 4.18 MiB | 29.74 MiB/s, done.
# Resolving deltas: 100% (110/110), done.
# Submodule path 'Imbalanced-Regression-DataSets': checked out 'db9f4d2d7dfccaf4165374cb5da6a389aa16d070'

# %%
# Хороший AutoMl для регрессии
# !pip  install tpot
# Out:
# Collecting tpot
#   Downloading TPOT-0.12.1-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.4/87.4 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.16.3 in /usr/local/lib/python3.10/dist-packages (from tpot) (1.23.5)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from tpot) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.10/dist-packages (from tpot) (1.2.2)
# Collecting deap>=1.2 (from tpot)
#   Downloading deap-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.4/135.4 kB 16.5 MB/s eta 0:00:00
# Collecting update-checker>=0.16 (from tpot)
#   Downloading update_checker-0.18.0-py3-none-any.whl (7.0 kB)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.10/dist-packages (from tpot) (4.66.1)
# Collecting stopit>=1.1.1 (from tpot)
#   Downloading stopit-1.1.2.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.10/dist-packages (from tpot) (1.5.3)
# Requirement already satisfied: joblib>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from tpot) (1.3.2)
# Requirement already satisfied: xgboost>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tpot) (1.7.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.2->tpot) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.2->tpot) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.0->tpot) (3.2.0)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from update-checker>=0.16->tpot) (2.31.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=0.24.2->tpot) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2023.7.22)
# Building wheels for collected packages: stopit
#   Building wheel for stopit (setup.py) ... done
#   Created wheel for stopit: filename=stopit-1.1.2-py3-none-any.whl size=11939 sha256=43a8fcf702806cab09d502503fc42f2b5edf2b93dc91076d6754276f94e509e7
#   Stored in directory: /root/.cache/pip/wheels/af/f9/87/bf5b3d565c2a007b4dae9d8142dccc85a9f164e517062dd519
# Successfully built stopit
# Installing collected packages: stopit, deap, update-checker, tpot
# Successfully installed deap-1.4.1 stopit-1.1.2 tpot-0.12.1 update-checker-0.18.0

# %%
# Еще один AutoML
# !pip install flaml
# Out:
# Collecting flaml
#   Downloading FLAML-2.0.2-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.3/295.3 kB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: NumPy>=1.17.0rc1 in /usr/local/lib/python3.10/dist-packages (from flaml) (1.23.5)
# Installing collected packages: flaml
# Successfully installed flaml-2.0.2

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %%
#@title Импортируем Библиотеки
import os

import numpy as np
import pandas as pd
from pandas.io.formats.format import NA

import catboost as cb

from sklearn.metrics import classification_report, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

import shap
import matplotlib.pyplot as plt
from matplotlib.animation import FFMpegWriter
import matplotlib.animation as animation
import seaborn as sns

import sweetviz as sw
# %matplotlib inline

#from gsmote import GeometricSMOTE

# очистка ОЗУ
import gc

import warnings
warnings.filterwarnings('ignore')
# Out:
# Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)

# %%
#@title Монтируем Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#@title Конструрование, очистка и анализ данных
PATH = '/content/drive/MyDrive/Warfarin/'
fname = PATH+'all_19.xls'  #Файл Сергея
df = pd.read_excel(fname)

#df.Diag = df.Diag.astype('category') #Диагнозыы и сердечно-сосудистые события
#df.sss = df.sss.astype('category')    # превращаем в категориальные данные
 # !!! Важно для правильного вычисления разностных данных сортируем данные по пациенту
 # и дате анализа

#df.sort_values(by=['IndPats', 'AnalisDate'], inplace=True)
'''
#Конструируем дифференциальные признаки
# Теперь добавляем всю историю в виде разности текущего и предыдущего показания
sample =1
df['Sample'] = 1
print(f'Было {fname}:{df.shape[0]} записей')
for i in range(1,df.shape[0]):
  if df.IndPats.iloc[i] == df.IndPats.iloc[i-1]:
    sample +=1
    if f'delta_date{sample}' not in df.columns():
      df[f'delta_date{sample}'] = None
      df[f'delta_MNO{sample}'] = None
      df[f'delta_mg{sample}'] = None
    for s in sample:
      df[f'delta_date{sample}']
    df['Prev_MG'].iloc[i] = df.mg.iloc[i-1]
    df['prev_MNO'].iloc[i] = df.MNO.iloc[i-1]
    df['date_diff'].iloc[i] = (df.AnalisDate.iloc[i]-df.AnalisDate.iloc[i-1]).days
  else:
    sample = 1
  df['Sample'].iloc[i] = sample
'''
# Убираем выбросы

df.reset_index()
#df = df[np.abs(df.age-df.age.mean()) <= (3*df.age.std())]
mno_iqr = df.mno.quantile(0.75)-df.mno.quantile(.25)
mg_iqr = df.dose_mg.quantile(0.75)-df.dose_mg.quantile(.25)
df = df[np.abs(df.mno-df.mno.mean()) <= (3*mno_iqr)]
df = df[np.abs(df.dose_mg-df.dose_mg.mean()) <= (3*mg_iqr)]
'''
# Парсим категории
df.Diag = df.Diag.astype('category')
df.sss = df.sss.astype('category')

df = pd.get_dummies(df, prefix=['Diag','sss'])
# разбираем парные диагнозы на еденичные
df.Diag_1.loc[(df['Diag_7']==1)
              |(df['Diag_9']==1)
              |(df['Diag_11']==1)] = 1 #Парсим ФП
df.Diag_2.loc[(df['Diag_7']==1)
              |(df['Diag_8']==1)
              |(df['Diag_10']==1)
              |(df['Diag_12']==1)
              |(df['Diag_14']==1)] =1  #Парсим ПС
df.Diag_3.loc[(df['Diag_8']==1)
              |(df['Diag_9']==1)
              |(df['Diag_11']==1)] = 1 #Парсим ИБС
df.Diag_4.loc[df['Diag_10']==1] = 1 #Парсим ИБС
df.Diag_6.loc[(df['Diag_12']==1)
              |(df['Diag_13']==1)
              |(df['Diag_14']==1)] = 1 #Парсим Ревм
# Теперь сердечно-сосудистые события
df.sss_3.loc[(df['sss_10']==1)] = 1   #Парсим Кс
df.sss_4.loc[(df['sss_9']==1)
              |(df['sss_11']==1)
              |(df['sss_13']==1)] = 1 #Парсим ПК
df.sss_5.loc[(df['sss_9']==1)
              |(df['sss_10']==1)
              |(df['sss_12']==1)
              |(df['sss_13']==1)] = 1 #Парсим КШ
df.sss_6.loc[(df['sss_11']==1)] = 1   #Парсим СТ
# Убираем лишнее
df.drop(columns =  ['Diag_7','Diag_8','Diag_9','Diag_10','Diag_11','Diag_12','Diag_13','Diag_14'],inplace=True)
df.drop(columns =  ['sss_1','sss_10','sss_11','sss_12','sss_13'],inplace=True)
#df = pd.concat([df,pd.get_dummies(df, columns=['sss'], prefix='sss')])

#превращаем возраст в AGE_RANGE равные возрастные группы
AGE_RANGE = 3
range_list = np.linspace(0, 1, AGE_RANGE+1, endpoint=0)
range_list = range_list[1:]
age_q = df.age.quantile(range_list).to_numpy()
df['age'+f'{int(age_q[0])}'] = (df.age < age_q[0]).astype(int) # First Value
for i in range(1,AGE_RANGE-1):
  df['age'+f'{int(age_q[i])}'] = ((df.age >= age_q[i]) & (df.age <age_q[i+1])).astype(int)
df['age'+f'{int(age_q[AGE_RANGE-1])}'] = (df.age >= age_q[AGE_RANGE-1]).astype(int) # LAST Value
#print(f'{[(range_list[i],age_q[i]) for i in range(AGE_RANGE)]}')

df.drop(columns='AnalisDate',inplace=True)
'''
print(f'Стало {fname}:{df.shape[0]} записей')
# Пишем Файл
df.reset_index()
with pd.ExcelWriter(fname[:-5]+'_dif.xlsx') as writer:
  df.to_excel(writer, sheet_name="Sheet1",index=False)
# Out:
# Стало /content/drive/MyDrive/Warfarin/all_19.xls:1515 записей

# %%
#@title Интерпретируем результат
ar = sw.analyze(df)
ar.show_notebook()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# !function(e,t){&quot;use strict&quot;;&quot;object&quot;==typeof module&amp;&amp;&quot;object&quot;==typeof module.exports?module.exports=e.document?t(e,!0):function(e){if(!e.document)throw new Error(&quot;jQuery requires a window with a document&quot;);return t(e)}:t(e)}(&quot;undefined&quot;!=typeof window?window:this,function(C,e){&quot;use strict&quot;;var t=[],E=C.document,r=Object.getPrototypeOf,s=t.slice,g=t.concat,u=t.push,i=t.indexOf,n={},o=n.toString,v=n.hasOwnProperty,a=v.toString,l=a.call(Object),y={},m=function(e){return&quot;function&quot;==typeof e&amp;&amp;&quot;number&quot;!=typeof e.nodeType},x=function(e){return null!=e&amp;&amp;e===e.window},c={type:!0,src:!0,nonce:!0,noModule:!0};function b(e,t,n){var r,i,o=(n=n||E).createElement(&quot;script&quot;);if(o.text=e,t)for(r in c)(i=t[r]||t.getAttribute&amp;&amp;t.getAttribute(r))&amp;&amp;o.setAttribute(r,i);n.head.appendChild(o).parentNode.removeChild(o)}function w(e){return null==e?e+&quot;&quot;:&quot;object&quot;==typeof e||&quot;function&quot;==typeof e?n[o.call(e)]||&quot;object&quot;:typeof e}var f=&quot;3.4.1&quot;,k=function(e,t){return new k.fn.init(e,t)},p=/^[\s\uFEFF\xA0]+|[\s\uFEFF\xA0]+$/g;function d(e){var t=!!e&amp;&amp;&quot;length&quot;in e&amp;&amp;e.length,n=w(e);return!m(e)&amp;&amp;!x(e)&amp;&amp;(&quot;array&quot;===n||0===t||&quot;number&quot;==typeof t&amp;&amp;0&lt;t&amp;&amp;t-1 in e)}k.fn=k.prototype={jquery:f,constructor:k,length:0,toArray:function(){return s.call(this)},get:function(e){return null==e?s.call(this):e&lt;0?this[e+this.length]:this[e]},pushStack:function(e){var t=k.merge(this.constructor(),e);return t.prevObject=this,t},each:function(e){return k.each(this,e)},map:function(n){return this.pushStack(k.map(this,function(e,t){return n.call(e,t,e)}))},slice:function(){return this.pushStack(s.apply(this,arguments))},first:function(){return this.eq(0)},last:function(){return this.eq(-1)},eq:function(e){var t=this.length,n=+e+(e&lt;0?t:0);return this.pushStack(0&lt;=n&amp;&amp;n&lt;t?[this[n]]:[])},end:function(){return this.prevObject||this.constructor()},push:u,sort:t.sort,splice:t.splice},k.extend=k.fn.extend=function(){var e,t,n,r,i,o,a=arguments[0]||{},s=1,u=arguments.length,l=!1;for(&quot;boolean&quot;==typeof a&amp;&amp;(l=a,a=arguments[s]||{},s++),&quot;object&quot;==typeof a||m(a)||(a={}),s===u&amp;&amp;(a=this,s--);s&lt;u;s++)if(null!=(e=arguments[s]))for(t in e)r=e[t],&quot;__proto__&quot;!==t&amp;&amp;a!==r&amp;&amp;(l&amp;&amp;r&amp;&amp;(k.isPlainObject(r)||(i=Array.isArray(r)))?(n=a[t],o=i&amp;&amp;!Array.isArray(n)?[]:i||k.isPlainObject(n)?n:{},i=!1,a[t]=k.extend(l,o,r)):void 0!==r&amp;&amp;(a[t]=r));return a},k.extend({expando:&quot;jQuery&quot;+(f+Math.random()).replace(/\D/g,&quot;&quot;),isReady:!0,error:function(e){throw new Error(e)},noop:function(){},isPlainObject:function(e){var t,n;return!(!e||&quot;[object Object]&quot;!==o.call(e))&amp;&amp;(!(t=r(e))||&quot;function&quot;==typeof(n=v.call(t,&quot;constructor&quot;)&amp;&amp;t.constructor)&amp;&amp;a.call(n)===l)},isEmptyObject:function(e){var t;for(t in e)return!1;return!0},globalEval:function(e,t){b(e,{nonce:t&amp;&amp;t.nonce})},each:function(e,t){var n,r=0;if(d(e)){for(n=e.length;r&lt;n;r++)if(!1===t.call(e[r],r,e[r]))break}else for(r in e)if(!1===t.call(e[r],r,e[r]))break;return e},trim:function(e){return null==e?&quot;&quot;:(e+&quot;&quot;).replace(p,&quot;&quot;)},makeArray:function(e,t){var n=t||[];return null!=e&amp;&amp;(d(Object(e))?k.merge(n,&quot;string&quot;==typeof e?[e]:e):u.call(n,e)),n},inArray:function(e,t,n){return null==t?-1:i.call(t,e,n)},merge:function(e,t){for(var n=+t.length,r=0,i=e.length;r&lt;n;r++)e[i++]=t[r];return e.length=i,e},grep:function(e,t,n){for(var r=[],i=0,o=e.length,a=!n;i&lt;o;i++)!t(e[i],i)!==a&amp;&amp;r.push(e[i]);return r},map:function(e,t,n){var r,i,o=0,a=[];if(d(e))for(r=e.length;o&lt;r;o++)null!=(i=t(e[o],o,n))&amp;&amp;a.push(i);else for(o in e)null!=(i=t(e[o],o,n))&amp;&amp;a.push(i);return g.apply([] ...

# %%
from sklearn.ensemble import IsolationForest
from imblearn.under_sampling import NearMiss
from sklearn.model_selection import train_test_split

from scipy import stats

# Формируем 2 Датасета df1 x_test1 y_test1 - там где у нас нет предистории
# и df x_test,y_test там где есть

#df.dropna(inplace=True)
df = pd.read_excel(os.path.join(PATH,fname[:-5]+'_dif.xlsx'))
df.dropna(inplace=True)   # убираем пустые значения
# Формируем тренировочную и тестовые выборки
train,test = train_test_split(df,test_size=0.2, random_state=33)

names = df.columns.tolist() # список имен колонок


names.remove('dose_mg')  # Это целевой столбец

print(names)

x_train = train[names].to_numpy()
y_train = train['dose_mg'].to_numpy()
x_test = test[names].to_numpy()
y_test = test['dose_mg'].to_numpy().astype('float')


print(x_train.shape,y_train.shape,x_test.shape,y_test.shape)

#x_train = X_train
#y_train = Y_train
# Out:
# ['sex', 'mno', 'mno2', '10-38', '38-66', '66-94', 'd_fibril', 'd_inorodnie', 'd_kombinacia', 'd_poroki', 'd_prochie']
# (1212, 11) (1212,) (303, 11) (303,)

# %%
# %pdb on

# %%
#@title Пробуем аугментацию
if False:'''
#import smogn
from SMOGN import smogn

#print(train.columns)
print(train.shape)
#print(train.info())
#train.drop(columns = 'AnalisDate',inplace=True)
#print(train.columns)
#smogn.box_plot_stats(train['MNO'])['stats']
#train.reset_index(inplace=True)
sm = smogn.SMOGN(threshold=0.9, over_sampling_ratio = 0.05,relevanse_base=0.5)
train_smogn = sm.fit_transform(train,'mno')
'''

# %%
#@title Базовая модель
from IPython.display import HTML

# Display the plotly visualization in the notebook
#HTML(filename='catboost_info/learn.html')

from catboost import CatBoostRegressor
from sklearn.model_selection import KFold
K = 5
kf = KFold(n_splits = K, random_state = 1, shuffle = True) # используем кросс-валидацию
cat = CatBoostRegressor()
cat1 = CatBoostRegressor()
cat.fit(x_train,y_train,verbose=False, plot=False)
from catboost import Pool, cv
params = {"iterations": 3000,
          "depth": 2,
          "loss_function": "MAPE",
          "boosting_type" : 'Ordered',
          "verbose": False}
cv_dataset = Pool(data=x_train,
                  label=y_train)

# %%
mape =[]
mae =[]
y_pred = cat.predict(x_test)
for i in range(y_test.shape[0]):
  mae1 = abs(y_test[i]-y_pred[i])
  m = mae1 /y_test[i]
  mape.append(m)
  mae.append(mae1)
mape = np.asarray(mape)
mae = np.asarray(mae)
r2=r2_score(y_test,y_pred)
indexes = np.argsort(y_test)
plt.plot(y_test[indexes],mae[indexes], label = 'MAE')
plt.show()
print(f'Средний показатель mg:{y_pred.mean()}, MAPE = {mape.mean()*100} МАЕ = {mae.mean()} R2 = {r2}')
print(f'Процент значений >0.5мг {(mae > 0.5).sum()/mae.shape*100}%')
print(f'MAE quantile 90% {np.quantile(mae,0.9)}')
# Out:
# Средний показатель mg:0.2826189737690042, MAPE = 40.941649232224655 МАЕ = 0.09409197811536253 R2 = 0.07815689274563009
# Процент значений >0.5мг [0.330033]%
# MAE quantile 90% 0.1863422933951141

# %%
#@title Объяснялки
explainer = shap.Explainer(cat)
shap_values = explainer(x_test)
#shap.plots.waterfall(shap_values[0])
shap.summary_plot(shap_values, plot_type = 'bar', feature_names = names)

# %%
cat.plot_tree(tree_idx=0)

# %%
#@title TPOT (фреймворк AUTOML)
from tpot import TPOTRegressor
tpot = TPOTRegressor(generations=5, population_size=25, verbosity=2, random_state=42)
tpot.fit(x_train, y_train)
print(tpot.score(x_test, y_test))
tpot.export('tpot_warfarin_pipeline.py')
# Out:
# Optimization Progress:   0%|          | 0/150 [00:00<?, ?pipeline/s]
# Generation 1 - Current best internal CV score: -0.012850402400224864
#
# Generation 2 - Current best internal CV score: -0.012850402400224864
#
# Generation 3 - Current best internal CV score: -0.012850402400224864
#
# Generation 4 - Current best internal CV score: -0.012764337634649413
#
# Generation 5 - Current best internal CV score: -0.012764337634649413
#
# Best pipeline: AdaBoostRegressor(ElasticNetCV(input_matrix, l1_ratio=0.75, tol=0.01), learning_rate=0.001, loss=square, n_estimators=100)
# -0.015296396180832703

# %% [markdown]
# В результате работы модели формируется Python файл, из которго в Ноутбуке я использую только настроенный регрессор

# %%
from sklearn.pipeline import make_pipeline

from sklearn.preprocessing import RobustScaler,StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.decomposition import FastICA
from sklearn.linear_model import LassoLarsCV
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import ElasticNetCV
from sklearn.preprocessing import Binarizer
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.pipeline import make_pipeline, make_union
from tpot.builtins import StackingEstimator
from tpot.export_utils import set_param_recursive
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.cluster import FeatureAgglomeration
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import VarianceThreshold
from xgboost import XGBRegressor
from sklearn.ensemble import AdaBoostRegressor

from tpot.builtins import ZeroCount
training_features, testing_features, training_target, testing_target = \
  x_train,x_test,y_train,y_test

# Average CV score on the training set was: -0.1886107689462097
#exported_pipeline = RandomForestRegressor(bootstrap=False, max_features=0.8500000000000001, min_samples_leaf=7, min_samples_split=7, n_estimators=100)
#exported_pipeline = RandomForestRegressor(bootstrap=True, max_features=0.7500000000000001, min_samples_leaf=4, min_samples_split=9, n_estimators=100)
#exported_pipeline = RandomForestRegressor(bootstrap=False, max_features=0.7500000000000001, min_samples_leaf=2, min_samples_split=2, n_estimators=100)
#exported_pipeline = ExtraTreesRegressor(bootstrap=True, max_features=0.8500000000000001, min_samples_leaf=1, min_samples_split=18, n_estimators=100)
# Average CV score on the training set was: -1.0753640232580637
#exported_pipeline = make_pipeline(ZeroCount(),ExtraTreesRegressor(bootstrap=False, max_features=0.1, min_samples_leaf=2, min_samples_split=2, n_estimators=100))
# Average CV score on the training set was: -1.079276849206908
#exported_pipeline = make_pipeline( ZeroCount(),ExtraTreesRegressor(bootstrap=False, max_features=0.2, min_samples_leaf=2, min_samples_split=19, n_estimators=100))
# Average CV score on the training set was: -0.7184865002928055
#exported_pipeline = make_pipeline( FeatureAgglomeration(affinity="euclidean", linkage="complete"),KNeighborsRegressor(n_neighbors=35, p=2, weights="distance"))
# Average CV score on the training set was: -0.6667361929601787
#exported_pipeline = make_pipeline(FeatureAgglomeration(affinity="l2", linkage="complete"),KNeighborsRegressor(n_neighbors=6, p=2, weights="distance"))
exported_pipeline = make_pipeline(
    StackingEstimator(estimator=ElasticNetCV(l1_ratio=0.75, tol=0.01)),
    AdaBoostRegressor(learning_rate=0.001, loss="square", n_estimators=100)
)
# Fix random state in exported estimator
if hasattr(exported_pipeline, 'random_state'):
    setattr(exported_pipeline, 'random_state', 42)
# Fix random state in exported estimator
if hasattr(exported_pipeline, 'random_state'):
    setattr(exported_pipeline, 'random_state', 42)
# Average CV score on the training set was: -2.444733968140026
exported_pipeline.fit(training_features, training_target)
y_pred = exported_pipeline.predict(testing_features)
mape =[]
mae =[]
#r2 = []
for i in range(y_test.shape[0]):
  mae1 = abs(y_test[i]-y_pred[i])
  m = mae1 /y_test[i]
  mape.append(m)
  mae.append(mae1)
  r2=r2_score(y_test,y_pred)
mape = np.asarray(mape)
mae = np.asarray(mae)
#r2 = np.asarray(r2)

print(f'Средний показатель Мг:{y_pred.mean()}, MAPE = {mape.mean()*100} МАЕ = {mae.mean()} R2 = {r2}')
print(f'Процент значений >0.5мг {(mae > 0.5).sum()/mae.shape*100}%')
print(f'MAE quantile 72% {np.quantile(mae,0.72)}')
indexes = np.argsort(y_test)
plt.plot(y_test[indexes],mae[indexes], label = 'MAE')
plt.show()
# Out:
# Средний показатель Мг:0.27921560544938034, MAPE = 41.01246718701176 МАЕ = 0.09413306882619413 R2 = 0.07428708456904731
# Процент значений >0.5мг [0.66006601]%
# MAE quantile 72% 0.12561168393075278

# %%
#@title Объяснялки
explainer = shap.Explainer(exported_pipeline)
shap_values = explainer(x_test)
#shap.plots.waterfall(shap_values[0])
shap.summary_plot(shap_values, plot_type = 'bar', feature_names = names)

# %%
#@title AUTOML
from flaml import AutoML
# Initialize an AutoML instance
automl = AutoML()
# Specify automl goal and constraint
automl_settings = {
    "time_budget": 120,  # in seconds
    "metric": 'r2',
    "task": 'regression',
    "log_file_name": "warfarin.log",
}
# Train with labeled input data
automl.fit(X_train=x_train, y_train=y_train,
           **automl_settings)
# Print the best model
print(automl.model.estimator)
# Out:
# [flaml.automl.logger: 09-02 19:06:13] {1679} INFO - task = regression
# [flaml.automl.logger: 09-02 19:06:13] {1690} INFO - Evaluation method: cv
# [flaml.automl.logger: 09-02 19:06:13] {1788} INFO - Minimizing error metric: 1-r2
# [flaml.automl.logger: 09-02 19:06:13] {1900} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'catboost', 'xgboost', 'extra_tree', 'xgb_limitdepth']
# [flaml.automl.logger: 09-02 19:06:13] {2218} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:13] {2344} INFO - Estimated sufficient time budget=697s. Estimated necessary time budget=6s.
# [flaml.automl.logger: 09-02 19:06:13] {2391} INFO -  at 0.1s,	estimator lgbm's best error=0.9709,	best estimator lgbm's best error=0.9709
# [flaml.automl.logger: 09-02 19:06:13] {2218} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:13] {2391} INFO -  at 0.1s,	estimator lgbm's best error=0.9709,	best estimator lgbm's best error=0.9709
# [flaml.automl.logger: 09-02 19:06:13] {2218} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:13] {2391} INFO -  at 0.1s,	estimator lgbm's best error=0.9458,	best estimator lgbm's best error=0.9458
# [flaml.automl.logger: 09-02 19:06:13] {2218} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:13] {2391} INFO -  at 0.2s,	estimator lgbm's best error=0.9458,	best estimator lgbm's best error=0.9458
# [flaml.automl.logger: 09-02 19:06:13] {2218} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:13] {2391} INFO -  at 0.2s,	estimator lgbm's best error=0.9458,	best estimator lgbm's best error=0.9458
# [flaml.automl.logger: 09-02 19:06:13] {2218} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:13] {2391} INFO -  at 0.2s,	estimator lgbm's best error=0.9458,	best estimator lgbm's best error=0.9458
# [flaml.automl.logger: 09-02 19:06:13] {2218} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:13] {2391} INFO -  at 0.3s,	estimator lgbm's best error=0.9458,	best estimator lgbm's best error=0.9458
# [flaml.automl.logger: 09-02 19:06:13] {2218} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:13] {2391} INFO -  at 0.3s,	estimator lgbm's best error=0.9368,	best estimator lgbm's best error=0.9368
# [flaml.automl.logger: 09-02 19:06:13] {2218} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:13] {2391} INFO -  at 0.3s,	estimator lgbm's best error=0.9297,	best estimator lgbm's best error=0.9297
# [flaml.automl.logger: 09-02 19:06:13] {2218} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:13] {2391} INFO -  at 0.3s,	estimator lgbm's best error=0.9297,	best estimator lgbm's best error=0.9297
# [flaml.automl.logger: 09-02 19:06:13] {2218} INFO - iteration 10, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:13] {2391} INFO -  at 0.4s,	estimator lgbm's best error=0.9297,	best estimator lgbm's best error=0.9297
# [flaml.automl.logger: 09-02 19:06:13] {2218} INFO - iteration 11, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:13] {2391} INFO -  at 0.4s,	estimator lgbm's best error=0.9297,	best estimator lgbm's best error=0.9297
# [flaml.automl.logger: 09-02 19:06:13] {2218} INFO - iteration 12, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:13] {2391} INFO -  at 0.4s,	estimator lgbm's best error=0.9297,	best estimator lgbm's best error=0.9297
# [flaml.automl.logger: 09-02 19:06:13] {2218} INFO - iteration 13, current learner xgboost
# [flaml.automl.logger: 09-02 19:06:13] {2391} INFO -  at 0.5s,	estimator xgboost's best error=2.4802,	best estimator lgbm's best error=0.9297
# [flaml.automl.logger: 09-02 19:06:13] {2218} INFO - iteration 14, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:14] {2391} INFO -  at 0.5s,	estimator lgbm's best error=0.9297,	best estimator lgbm's best error=0.9297
# [flaml.automl.logger: 09-02 19:06:14] {2218} INFO - iteration 15, current learner xgboost
# [flaml.automl.logger: 09-02 19:06:14] {2391} INFO -  at 0.6s,	estimator xgboost's best error=2.4802,	best estimator lgbm's best error=0.9297
# [flaml.automl.logger: 09-02 19:06:14] {2218} INFO - iteration 16, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:14] {2391} INFO -  at 0.6s,	estimator lgbm's best error=0.9297,	best estimator lgbm's best error=0.9297
# [flaml.automl.logger: 09-02 19:06:14] {2218} INFO - iteration 17, current learner xgboost
# [flaml.automl.logger: 09-02 19:06:14] {2391} INFO -  at 0.6s,	estimator xgboost's best error=1.2623,	best estimator lgbm's best error=0.9297
# [flaml.automl.logger: 09-02 19:06:14] {2218} INFO - iteration 18, current learner xgboost
# [flaml.automl.logger: 09-02 19:06:14] {2391} INFO -  at 0.7s,	estimator xgboost's best error=0.9640,	best estimator lgbm's best error=0.9297
# [flaml.automl.logger: 09-02 19:06:14] {2218} INFO - iteration 19, current learner xgboost
# [flaml.automl.logger: 09-02 19:06:14] {2391} INFO -  at 0.7s,	estimator xgboost's best error=0.9640,	best estimator lgbm's best error=0.9297
# [flaml.automl.logger: 09-02 19:06:14] {2218} INFO - iteration 20, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:14] {2391} INFO -  at 0.8s,	estimator lgbm's best error=0.9297,	best estimator lgbm's best error=0.9297
# [flaml.automl.logger: 09-02 19:06:14] {2218} INFO - iteration 21, current learner xgboost
# [flaml.automl.logger: 09-02 19:06:14] {2391} INFO -  at 0.8s,	estimator xgboost's best error=0.9413,	best estimator lgbm's best error=0.9297
# [flaml.automl.logger: 09-02 19:06:14] {2218} INFO - iteration 22, current learner xgboost
# [flaml.automl.logger: 09-02 19:06:14] {2391} INFO -  at 0.8s,	estimator xgboost's best error=0.9413,	best estimator lgbm's best error=0.9297
# [flaml.automl.logger: 09-02 19:06:14] {2218} INFO - iteration 23, current learner xgboost
# [flaml.automl.logger: 09-02 19:06:14] {2391} INFO -  at 0.9s,	estimator xgboost's best error=0.9413,	best estimator lgbm's best error=0.9297
# [flaml.automl.logger: 09-02 19:06:14] {2218} INFO - iteration 24, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:14] {2391} INFO -  at 1.0s,	estimator extra_tree's best error=0.9491,	best estimator lgbm's best error=0.9297
# [flaml.automl.logger: 09-02 19:06:14] {2218} INFO - iteration 25, current learner rf
# [flaml.automl.logger: 09-02 19:06:14] {2391} INFO -  at 1.2s,	estimator rf's best error=0.9317,	best estimator lgbm's best error=0.9297
# [flaml.automl.logger: 09-02 19:06:14] {2218} INFO - iteration 26, current learner rf
# [flaml.automl.logger: 09-02 19:06:14] {2391} INFO -  at 1.4s,	estimator rf's best error=0.9311,	best estimator lgbm's best error=0.9297
# [flaml.automl.logger: 09-02 19:06:14] {2218} INFO - iteration 27, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:15] {2391} INFO -  at 1.5s,	estimator extra_tree's best error=0.9454,	best estimator lgbm's best error=0.9297
# [flaml.automl.logger: 09-02 19:06:15] {2218} INFO - iteration 28, current learner xgboost
# [flaml.automl.logger: 09-02 19:06:15] {2391} INFO -  at 1.6s,	estimator xgboost's best error=0.9413,	best estimator lgbm's best error=0.9297
# [flaml.automl.logger: 09-02 19:06:15] {2218} INFO - iteration 29, current learner xgboost
# [flaml.automl.logger: 09-02 19:06:15] {2391} INFO -  at 1.6s,	estimator xgboost's best error=0.9413,	best estimator lgbm's best error=0.9297
# [flaml.automl.logger: 09-02 19:06:15] {2218} INFO - iteration 30, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:15] {2391} INFO -  at 1.7s,	estimator lgbm's best error=0.9297,	best estimator lgbm's best error=0.9297
# [flaml.automl.logger: 09-02 19:06:15] {2218} INFO - iteration 31, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:15] {2391} INFO -  at 1.7s,	estimator lgbm's best error=0.9297,	best estimator lgbm's best error=0.9297
# [flaml.automl.logger: 09-02 19:06:15] {2218} INFO - iteration 32, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:15] {2391} INFO -  at 1.7s,	estimator lgbm's best error=0.9297,	best estimator lgbm's best error=0.9297
# [flaml.automl.logger: 09-02 19:06:15] {2218} INFO - iteration 33, current learner xgboost
# [flaml.automl.logger: 09-02 19:06:15] {2391} INFO -  at 1.8s,	estimator xgboost's best error=0.9413,	best estimator lgbm's best error=0.9297
# [flaml.automl.logger: 09-02 19:06:15] {2218} INFO - iteration 34, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:15] {2391} INFO -  at 1.8s,	estimator lgbm's best error=0.9297,	best estimator lgbm's best error=0.9297
# [flaml.automl.logger: 09-02 19:06:15] {2218} INFO - iteration 35, current learner rf
# [flaml.automl.logger: 09-02 19:06:15] {2391} INFO -  at 2.0s,	estimator rf's best error=0.9263,	best estimator rf's best error=0.9263
# [flaml.automl.logger: 09-02 19:06:15] {2218} INFO - iteration 36, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:15] {2391} INFO -  at 2.1s,	estimator extra_tree's best error=0.9454,	best estimator rf's best error=0.9263
# [flaml.automl.logger: 09-02 19:06:15] {2218} INFO - iteration 37, current learner rf
# [flaml.automl.logger: 09-02 19:06:15] {2391} INFO -  at 2.3s,	estimator rf's best error=0.9263,	best estimator rf's best error=0.9263
# [flaml.automl.logger: 09-02 19:06:15] {2218} INFO - iteration 38, current learner rf
# [flaml.automl.logger: 09-02 19:06:15] {2391} INFO -  at 2.5s,	estimator rf's best error=0.9263,	best estimator rf's best error=0.9263
# [flaml.automl.logger: 09-02 19:06:15] {2218} INFO - iteration 39, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:16] {2391} INFO -  at 2.5s,	estimator lgbm's best error=0.9297,	best estimator rf's best error=0.9263
# [flaml.automl.logger: 09-02 19:06:16] {2218} INFO - iteration 40, current learner xgboost
# [flaml.automl.logger: 09-02 19:06:16] {2391} INFO -  at 2.5s,	estimator xgboost's best error=0.9413,	best estimator rf's best error=0.9263
# [flaml.automl.logger: 09-02 19:06:16] {2218} INFO - iteration 41, current learner xgboost
# [flaml.automl.logger: 09-02 19:06:16] {2391} INFO -  at 2.6s,	estimator xgboost's best error=0.9413,	best estimator rf's best error=0.9263
# [flaml.automl.logger: 09-02 19:06:16] {2218} INFO - iteration 42, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:16] {2391} INFO -  at 2.6s,	estimator lgbm's best error=0.9243,	best estimator lgbm's best error=0.9243
# [flaml.automl.logger: 09-02 19:06:16] {2218} INFO - iteration 43, current learner xgboost
# [flaml.automl.logger: 09-02 19:06:16] {2391} INFO -  at 2.6s,	estimator xgboost's best error=0.9413,	best estimator lgbm's best error=0.9243
# [flaml.automl.logger: 09-02 19:06:16] {2218} INFO - iteration 44, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:16] {2391} INFO -  at 2.8s,	estimator extra_tree's best error=0.9304,	best estimator lgbm's best error=0.9243
# [flaml.automl.logger: 09-02 19:06:16] {2218} INFO - iteration 45, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:16] {2391} INFO -  at 3.0s,	estimator extra_tree's best error=0.9304,	best estimator lgbm's best error=0.9243
# [flaml.automl.logger: 09-02 19:06:16] {2218} INFO - iteration 46, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:16] {2391} INFO -  at 3.0s,	estimator lgbm's best error=0.9243,	best estimator lgbm's best error=0.9243
# [flaml.automl.logger: 09-02 19:06:16] {2218} INFO - iteration 47, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:16] {2391} INFO -  at 3.2s,	estimator extra_tree's best error=0.9304,	best estimator lgbm's best error=0.9243
# [flaml.automl.logger: 09-02 19:06:16] {2218} INFO - iteration 48, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:16] {2391} INFO -  at 3.2s,	estimator lgbm's best error=0.9243,	best estimator lgbm's best error=0.9243
# [flaml.automl.logger: 09-02 19:06:16] {2218} INFO - iteration 49, current learner rf
# [flaml.automl.logger: 09-02 19:06:16] {2391} INFO -  at 3.4s,	estimator rf's best error=0.9263,	best estimator lgbm's best error=0.9243
# [flaml.automl.logger: 09-02 19:06:16] {2218} INFO - iteration 50, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:17] {2391} INFO -  at 3.6s,	estimator extra_tree's best error=0.9304,	best estimator lgbm's best error=0.9243
# [flaml.automl.logger: 09-02 19:06:17] {2218} INFO - iteration 51, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:17] {2391} INFO -  at 3.7s,	estimator lgbm's best error=0.9243,	best estimator lgbm's best error=0.9243
# [flaml.automl.logger: 09-02 19:06:17] {2218} INFO - iteration 52, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:17] {2391} INFO -  at 3.7s,	estimator lgbm's best error=0.9238,	best estimator lgbm's best error=0.9238
# [flaml.automl.logger: 09-02 19:06:17] {2218} INFO - iteration 53, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:17] {2391} INFO -  at 3.7s,	estimator lgbm's best error=0.9238,	best estimator lgbm's best error=0.9238
# [flaml.automl.logger: 09-02 19:06:17] {2218} INFO - iteration 54, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:17] {2391} INFO -  at 3.8s,	estimator lgbm's best error=0.9238,	best estimator lgbm's best error=0.9238
# [flaml.automl.logger: 09-02 19:06:17] {2218} INFO - iteration 55, current learner rf
# [flaml.automl.logger: 09-02 19:06:17] {2391} INFO -  at 3.9s,	estimator rf's best error=0.9263,	best estimator lgbm's best error=0.9238
# [flaml.automl.logger: 09-02 19:06:17] {2218} INFO - iteration 56, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:17] {2391} INFO -  at 4.0s,	estimator lgbm's best error=0.9238,	best estimator lgbm's best error=0.9238
# [flaml.automl.logger: 09-02 19:06:17] {2218} INFO - iteration 57, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:17] {2391} INFO -  at 4.0s,	estimator lgbm's best error=0.9238,	best estimator lgbm's best error=0.9238
# [flaml.automl.logger: 09-02 19:06:17] {2218} INFO - iteration 58, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:17] {2391} INFO -  at 4.1s,	estimator lgbm's best error=0.9238,	best estimator lgbm's best error=0.9238
# [flaml.automl.logger: 09-02 19:06:17] {2218} INFO - iteration 59, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:17] {2391} INFO -  at 4.1s,	estimator lgbm's best error=0.9238,	best estimator lgbm's best error=0.9238
# [flaml.automl.logger: 09-02 19:06:17] {2218} INFO - iteration 60, current learner rf
# [flaml.automl.logger: 09-02 19:06:17] {2391} INFO -  at 4.3s,	estimator rf's best error=0.9212,	best estimator rf's best error=0.9212
# [flaml.automl.logger: 09-02 19:06:17] {2218} INFO - iteration 61, current learner rf
# [flaml.automl.logger: 09-02 19:06:17] {2391} INFO -  at 4.5s,	estimator rf's best error=0.9212,	best estimator rf's best error=0.9212
# [flaml.automl.logger: 09-02 19:06:17] {2218} INFO - iteration 62, current learner xgboost
# [flaml.automl.logger: 09-02 19:06:18] {2391} INFO -  at 5.0s,	estimator xgboost's best error=0.9413,	best estimator rf's best error=0.9212
# [flaml.automl.logger: 09-02 19:06:18] {2218} INFO - iteration 63, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:18] {2391} INFO -  at 5.2s,	estimator extra_tree's best error=0.9304,	best estimator rf's best error=0.9212
# [flaml.automl.logger: 09-02 19:06:18] {2218} INFO - iteration 64, current learner rf
# [flaml.automl.logger: 09-02 19:06:18] {2391} INFO -  at 5.3s,	estimator rf's best error=0.9212,	best estimator rf's best error=0.9212
# [flaml.automl.logger: 09-02 19:06:18] {2218} INFO - iteration 65, current learner rf
# [flaml.automl.logger: 09-02 19:06:19] {2391} INFO -  at 5.6s,	estimator rf's best error=0.9211,	best estimator rf's best error=0.9211
# [flaml.automl.logger: 09-02 19:06:19] {2218} INFO - iteration 66, current learner xgboost
# [flaml.automl.logger: 09-02 19:06:20] {2391} INFO -  at 6.6s,	estimator xgboost's best error=0.9413,	best estimator rf's best error=0.9211
# [flaml.automl.logger: 09-02 19:06:20] {2218} INFO - iteration 67, current learner rf
# [flaml.automl.logger: 09-02 19:06:20] {2391} INFO -  at 6.8s,	estimator rf's best error=0.9211,	best estimator rf's best error=0.9211
# [flaml.automl.logger: 09-02 19:06:20] {2218} INFO - iteration 68, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:20] {2391} INFO -  at 6.8s,	estimator lgbm's best error=0.9238,	best estimator rf's best error=0.9211
# [flaml.automl.logger: 09-02 19:06:20] {2218} INFO - iteration 69, current learner rf
# [flaml.automl.logger: 09-02 19:06:20] {2391} INFO -  at 7.3s,	estimator rf's best error=0.9149,	best estimator rf's best error=0.9149
# [flaml.automl.logger: 09-02 19:06:20] {2218} INFO - iteration 70, current learner rf
# [flaml.automl.logger: 09-02 19:06:21] {2391} INFO -  at 7.6s,	estimator rf's best error=0.9149,	best estimator rf's best error=0.9149
# [flaml.automl.logger: 09-02 19:06:21] {2218} INFO - iteration 71, current learner rf
# [flaml.automl.logger: 09-02 19:06:21] {2391} INFO -  at 8.2s,	estimator rf's best error=0.9149,	best estimator rf's best error=0.9149
# [flaml.automl.logger: 09-02 19:06:21] {2218} INFO - iteration 72, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:21] {2391} INFO -  at 8.4s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9149
# [flaml.automl.logger: 09-02 19:06:21] {2218} INFO - iteration 73, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:22] {2391} INFO -  at 8.7s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9149
# [flaml.automl.logger: 09-02 19:06:22] {2218} INFO - iteration 74, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:22] {2391} INFO -  at 9.3s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9149
# [flaml.automl.logger: 09-02 19:06:22] {2218} INFO - iteration 75, current learner rf
# [flaml.automl.logger: 09-02 19:06:23] {2391} INFO -  at 9.6s,	estimator rf's best error=0.9149,	best estimator rf's best error=0.9149
# [flaml.automl.logger: 09-02 19:06:23] {2218} INFO - iteration 76, current learner catboost
# [flaml.automl.logger: 09-02 19:06:23] {2391} INFO -  at 9.9s,	estimator catboost's best error=0.9311,	best estimator rf's best error=0.9149
# [flaml.automl.logger: 09-02 19:06:23] {2218} INFO - iteration 77, current learner rf
# [flaml.automl.logger: 09-02 19:06:24] {2391} INFO -  at 10.8s,	estimator rf's best error=0.9149,	best estimator rf's best error=0.9149
# [flaml.automl.logger: 09-02 19:06:24] {2218} INFO - iteration 78, current learner xgboost
# [flaml.automl.logger: 09-02 19:06:24] {2391} INFO -  at 10.8s,	estimator xgboost's best error=0.9413,	best estimator rf's best error=0.9149
# [flaml.automl.logger: 09-02 19:06:24] {2218} INFO - iteration 79, current learner catboost
# [flaml.automl.logger: 09-02 19:06:24] {2391} INFO -  at 11.1s,	estimator catboost's best error=0.9311,	best estimator rf's best error=0.9149
# [flaml.automl.logger: 09-02 19:06:24] {2218} INFO - iteration 80, current learner catboost
# [flaml.automl.logger: 09-02 19:06:24] {2391} INFO -  at 11.4s,	estimator catboost's best error=0.9311,	best estimator rf's best error=0.9149
# [flaml.automl.logger: 09-02 19:06:24] {2218} INFO - iteration 81, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:25] {2391} INFO -  at 11.6s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9149
# [flaml.automl.logger: 09-02 19:06:25] {2218} INFO - iteration 82, current learner catboost
# [flaml.automl.logger: 09-02 19:06:25] {2391} INFO -  at 11.9s,	estimator catboost's best error=0.9311,	best estimator rf's best error=0.9149
# [flaml.automl.logger: 09-02 19:06:25] {2218} INFO - iteration 83, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:25] {2391} INFO -  at 12.3s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9149
# [flaml.automl.logger: 09-02 19:06:25] {2218} INFO - iteration 84, current learner xgboost
# [flaml.automl.logger: 09-02 19:06:25] {2391} INFO -  at 12.3s,	estimator xgboost's best error=0.9413,	best estimator rf's best error=0.9149
# [flaml.automl.logger: 09-02 19:06:25] {2218} INFO - iteration 85, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:26] {2391} INFO -  at 12.5s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9149
# [flaml.automl.logger: 09-02 19:06:26] {2218} INFO - iteration 86, current learner catboost
# [flaml.automl.logger: 09-02 19:06:26] {2391} INFO -  at 12.8s,	estimator catboost's best error=0.9307,	best estimator rf's best error=0.9149
# [flaml.automl.logger: 09-02 19:06:26] {2218} INFO - iteration 87, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:26] {2391} INFO -  at 13.1s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9149
# [flaml.automl.logger: 09-02 19:06:26] {2218} INFO - iteration 88, current learner rf
# [flaml.automl.logger: 09-02 19:06:27] {2391} INFO -  at 13.9s,	estimator rf's best error=0.9107,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:27] {2218} INFO - iteration 89, current learner rf
# [flaml.automl.logger: 09-02 19:06:27] {2391} INFO -  at 14.3s,	estimator rf's best error=0.9107,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:27] {2218} INFO - iteration 90, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:27] {2391} INFO -  at 14.5s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:27] {2218} INFO - iteration 91, current learner rf
# [flaml.automl.logger: 09-02 19:06:29] {2391} INFO -  at 15.8s,	estimator rf's best error=0.9107,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:29] {2218} INFO - iteration 92, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:29] {2391} INFO -  at 16.1s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:29] {2218} INFO - iteration 93, current learner xgboost
# [flaml.automl.logger: 09-02 19:06:29] {2391} INFO -  at 16.1s,	estimator xgboost's best error=0.9413,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:29] {2218} INFO - iteration 94, current learner xgboost
# [flaml.automl.logger: 09-02 19:06:29] {2391} INFO -  at 16.2s,	estimator xgboost's best error=0.9413,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:29] {2218} INFO - iteration 95, current learner rf
# [flaml.automl.logger: 09-02 19:06:30] {2391} INFO -  at 16.6s,	estimator rf's best error=0.9107,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:30] {2218} INFO - iteration 96, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:30] {2391} INFO -  at 16.9s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:30] {2218} INFO - iteration 97, current learner rf
# [flaml.automl.logger: 09-02 19:06:30] {2391} INFO -  at 17.4s,	estimator rf's best error=0.9107,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:30] {2218} INFO - iteration 98, current learner xgboost
# [flaml.automl.logger: 09-02 19:06:31] {2391} INFO -  at 17.5s,	estimator xgboost's best error=0.9413,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:31] {2218} INFO - iteration 99, current learner rf
# [flaml.automl.logger: 09-02 19:06:32] {2391} INFO -  at 19.3s,	estimator rf's best error=0.9107,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:32] {2218} INFO - iteration 100, current learner rf
# [flaml.automl.logger: 09-02 19:06:33] {2391} INFO -  at 20.2s,	estimator rf's best error=0.9107,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:33] {2218} INFO - iteration 101, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:06:33] {2391} INFO -  at 20.2s,	estimator xgb_limitdepth's best error=0.9828,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:33] {2218} INFO - iteration 102, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:06:33] {2391} INFO -  at 20.3s,	estimator xgb_limitdepth's best error=0.9828,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:33] {2218} INFO - iteration 103, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:06:33] {2391} INFO -  at 20.4s,	estimator xgb_limitdepth's best error=0.9828,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:33] {2218} INFO - iteration 104, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:33] {2391} INFO -  at 20.4s,	estimator lgbm's best error=0.9238,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:33] {2218} INFO - iteration 105, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:06:33] {2391} INFO -  at 20.5s,	estimator xgb_limitdepth's best error=0.9828,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:33] {2218} INFO - iteration 106, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:06:34] {2391} INFO -  at 20.6s,	estimator xgb_limitdepth's best error=0.9828,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:34] {2218} INFO - iteration 107, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:06:34] {2391} INFO -  at 20.6s,	estimator xgb_limitdepth's best error=0.9828,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:34] {2218} INFO - iteration 108, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:06:34] {2391} INFO -  at 20.7s,	estimator xgb_limitdepth's best error=0.9828,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:34] {2218} INFO - iteration 109, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:06:34] {2391} INFO -  at 20.8s,	estimator xgb_limitdepth's best error=0.9828,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:34] {2218} INFO - iteration 110, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:06:34] {2391} INFO -  at 20.9s,	estimator xgb_limitdepth's best error=0.9828,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:34] {2218} INFO - iteration 111, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:06:34] {2391} INFO -  at 21.0s,	estimator xgb_limitdepth's best error=0.9828,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:34] {2218} INFO - iteration 112, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:34] {2391} INFO -  at 21.0s,	estimator lgbm's best error=0.9238,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:34] {2218} INFO - iteration 113, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:06:34] {2391} INFO -  at 21.1s,	estimator xgb_limitdepth's best error=0.9659,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:34] {2218} INFO - iteration 114, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:34] {2391} INFO -  at 21.2s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:34] {2218} INFO - iteration 115, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:06:34] {2391} INFO -  at 21.3s,	estimator xgb_limitdepth's best error=0.9659,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:34] {2218} INFO - iteration 116, current learner rf
# [flaml.automl.logger: 09-02 19:06:35] {2391} INFO -  at 22.1s,	estimator rf's best error=0.9107,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:35] {2218} INFO - iteration 117, current learner rf
# [flaml.automl.logger: 09-02 19:06:37] {2391} INFO -  at 24.5s,	estimator rf's best error=0.9107,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:37] {2218} INFO - iteration 118, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:06:38] {2391} INFO -  at 25.1s,	estimator xgb_limitdepth's best error=0.9659,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:38] {2218} INFO - iteration 119, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:39] {2391} INFO -  at 25.6s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:39] {2218} INFO - iteration 120, current learner rf
# [flaml.automl.logger: 09-02 19:06:40] {2391} INFO -  at 26.5s,	estimator rf's best error=0.9107,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:40] {2218} INFO - iteration 121, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:40] {2391} INFO -  at 27.1s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:40] {2218} INFO - iteration 122, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:40] {2391} INFO -  at 27.5s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:40] {2218} INFO - iteration 123, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:06:41] {2391} INFO -  at 28.2s,	estimator xgb_limitdepth's best error=0.9659,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:41] {2218} INFO - iteration 124, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:42] {2391} INFO -  at 28.8s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:42] {2218} INFO - iteration 125, current learner rf
# [flaml.automl.logger: 09-02 19:06:43] {2391} INFO -  at 30.3s,	estimator rf's best error=0.9107,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:43] {2218} INFO - iteration 126, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:45] {2391} INFO -  at 32.2s,	estimator lgbm's best error=0.9238,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:45] {2218} INFO - iteration 127, current learner rf
# [flaml.automl.logger: 09-02 19:06:46] {2391} INFO -  at 33.5s,	estimator rf's best error=0.9107,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:46] {2218} INFO - iteration 128, current learner rf
# [flaml.automl.logger: 09-02 19:06:47] {2391} INFO -  at 34.0s,	estimator rf's best error=0.9107,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:47] {2218} INFO - iteration 129, current learner xgboost
# [flaml.automl.logger: 09-02 19:06:47] {2391} INFO -  at 34.1s,	estimator xgboost's best error=0.9413,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:47] {2218} INFO - iteration 130, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:06:47] {2391} INFO -  at 34.1s,	estimator xgb_limitdepth's best error=0.9659,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:47] {2218} INFO - iteration 131, current learner xgboost
# [flaml.automl.logger: 09-02 19:06:47] {2391} INFO -  at 34.2s,	estimator xgboost's best error=0.9413,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:47] {2218} INFO - iteration 132, current learner xgboost
# [flaml.automl.logger: 09-02 19:06:47] {2391} INFO -  at 34.2s,	estimator xgboost's best error=0.9413,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:47] {2218} INFO - iteration 133, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:06:47] {2391} INFO -  at 34.3s,	estimator xgb_limitdepth's best error=0.9659,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:47] {2218} INFO - iteration 134, current learner rf
# [flaml.automl.logger: 09-02 19:06:48] {2391} INFO -  at 35.3s,	estimator rf's best error=0.9107,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:48] {2218} INFO - iteration 135, current learner xgboost
# [flaml.automl.logger: 09-02 19:06:48] {2391} INFO -  at 35.3s,	estimator xgboost's best error=0.9413,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:48] {2218} INFO - iteration 136, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:49] {2391} INFO -  at 35.5s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:49] {2218} INFO - iteration 137, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:06:49] {2391} INFO -  at 35.6s,	estimator xgb_limitdepth's best error=0.9659,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:49] {2218} INFO - iteration 138, current learner xgboost
# [flaml.automl.logger: 09-02 19:06:49] {2391} INFO -  at 35.7s,	estimator xgboost's best error=0.9413,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:49] {2218} INFO - iteration 139, current learner rf
# [flaml.automl.logger: 09-02 19:06:50] {2391} INFO -  at 36.6s,	estimator rf's best error=0.9107,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:50] {2218} INFO - iteration 140, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:50] {2391} INFO -  at 36.8s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:50] {2218} INFO - iteration 141, current learner xgboost
# [flaml.automl.logger: 09-02 19:06:50] {2391} INFO -  at 36.8s,	estimator xgboost's best error=0.9301,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:50] {2218} INFO - iteration 142, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:50] {2391} INFO -  at 37.1s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:50] {2218} INFO - iteration 143, current learner xgboost
# [flaml.automl.logger: 09-02 19:06:50] {2391} INFO -  at 37.1s,	estimator xgboost's best error=0.9301,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:50] {2218} INFO - iteration 144, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:06:50] {2391} INFO -  at 37.2s,	estimator xgb_limitdepth's best error=0.9659,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:50] {2218} INFO - iteration 145, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:50] {2391} INFO -  at 37.4s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:50] {2218} INFO - iteration 146, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:51] {2391} INFO -  at 37.6s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:51] {2218} INFO - iteration 147, current learner rf
# [flaml.automl.logger: 09-02 19:06:51] {2391} INFO -  at 38.2s,	estimator rf's best error=0.9107,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:51] {2218} INFO - iteration 148, current learner rf
# [flaml.automl.logger: 09-02 19:06:52] {2391} INFO -  at 39.3s,	estimator rf's best error=0.9107,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:52] {2218} INFO - iteration 149, current learner rf
# [flaml.automl.logger: 09-02 19:06:53] {2391} INFO -  at 39.8s,	estimator rf's best error=0.9107,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:53] {2218} INFO - iteration 150, current learner rf
# [flaml.automl.logger: 09-02 19:06:53] {2391} INFO -  at 40.3s,	estimator rf's best error=0.9107,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:53] {2218} INFO - iteration 151, current learner rf
# [flaml.automl.logger: 09-02 19:06:55] {2391} INFO -  at 41.5s,	estimator rf's best error=0.9107,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:55] {2218} INFO - iteration 152, current learner xgboost
# [flaml.automl.logger: 09-02 19:06:55] {2391} INFO -  at 41.6s,	estimator xgboost's best error=0.9301,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:55] {2218} INFO - iteration 153, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:55] {2391} INFO -  at 41.8s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:55] {2218} INFO - iteration 154, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:55] {2391} INFO -  at 42.0s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:55] {2218} INFO - iteration 155, current learner lgbm
# [flaml.automl.logger: 09-02 19:06:55] {2391} INFO -  at 42.1s,	estimator lgbm's best error=0.9238,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:55] {2218} INFO - iteration 156, current learner rf
# [flaml.automl.logger: 09-02 19:06:56] {2391} INFO -  at 43.3s,	estimator rf's best error=0.9107,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:56] {2218} INFO - iteration 157, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:06:58] {2391} INFO -  at 44.6s,	estimator xgb_limitdepth's best error=0.9659,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:58] {2218} INFO - iteration 158, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:58] {2391} INFO -  at 44.8s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:58] {2218} INFO - iteration 159, current learner xgboost
# [flaml.automl.logger: 09-02 19:06:58] {2391} INFO -  at 45.1s,	estimator xgboost's best error=0.9301,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:58] {2218} INFO - iteration 160, current learner xgboost
# [flaml.automl.logger: 09-02 19:06:58] {2391} INFO -  at 45.2s,	estimator xgboost's best error=0.9301,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:58] {2218} INFO - iteration 161, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:58] {2391} INFO -  at 45.4s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:58] {2218} INFO - iteration 162, current learner catboost
# [flaml.automl.logger: 09-02 19:06:59] {2391} INFO -  at 45.7s,	estimator catboost's best error=0.9307,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:59] {2218} INFO - iteration 163, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:59] {2391} INFO -  at 46.0s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:59] {2218} INFO - iteration 164, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:06:59] {2391} INFO -  at 46.0s,	estimator xgb_limitdepth's best error=0.9436,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:59] {2218} INFO - iteration 165, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:06:59] {2391} INFO -  at 46.1s,	estimator xgb_limitdepth's best error=0.9436,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:59] {2218} INFO - iteration 166, current learner xgboost
# [flaml.automl.logger: 09-02 19:06:59] {2391} INFO -  at 46.2s,	estimator xgboost's best error=0.9301,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:59] {2218} INFO - iteration 167, current learner extra_tree
# [flaml.automl.logger: 09-02 19:06:59] {2391} INFO -  at 46.4s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:06:59] {2218} INFO - iteration 168, current learner extra_tree
# [flaml.automl.logger: 09-02 19:07:00] {2391} INFO -  at 46.6s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:00] {2218} INFO - iteration 169, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:07:00] {2391} INFO -  at 46.7s,	estimator xgb_limitdepth's best error=0.9436,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:00] {2218} INFO - iteration 170, current learner catboost
# [flaml.automl.logger: 09-02 19:07:00] {2391} INFO -  at 46.9s,	estimator catboost's best error=0.9307,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:00] {2218} INFO - iteration 171, current learner lgbm
# [flaml.automl.logger: 09-02 19:07:00] {2391} INFO -  at 47.0s,	estimator lgbm's best error=0.9238,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:00] {2218} INFO - iteration 172, current learner rf
# [flaml.automl.logger: 09-02 19:07:01] {2391} INFO -  at 47.5s,	estimator rf's best error=0.9107,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:01] {2218} INFO - iteration 173, current learner extra_tree
# [flaml.automl.logger: 09-02 19:07:01] {2391} INFO -  at 47.7s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:01] {2218} INFO - iteration 174, current learner extra_tree
# [flaml.automl.logger: 09-02 19:07:01] {2391} INFO -  at 47.9s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:01] {2218} INFO - iteration 175, current learner extra_tree
# [flaml.automl.logger: 09-02 19:07:01] {2391} INFO -  at 48.2s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:01] {2218} INFO - iteration 176, current learner xgboost
# [flaml.automl.logger: 09-02 19:07:01] {2391} INFO -  at 48.2s,	estimator xgboost's best error=0.9301,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:01] {2218} INFO - iteration 177, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:07:01] {2391} INFO -  at 48.3s,	estimator xgb_limitdepth's best error=0.9436,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:01] {2218} INFO - iteration 178, current learner extra_tree
# [flaml.automl.logger: 09-02 19:07:01] {2391} INFO -  at 48.5s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:01] {2218} INFO - iteration 179, current learner xgboost
# [flaml.automl.logger: 09-02 19:07:02] {2391} INFO -  at 48.5s,	estimator xgboost's best error=0.9301,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:02] {2218} INFO - iteration 180, current learner extra_tree
# [flaml.automl.logger: 09-02 19:07:02] {2391} INFO -  at 48.8s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:02] {2218} INFO - iteration 181, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:07:02] {2391} INFO -  at 48.8s,	estimator xgb_limitdepth's best error=0.9436,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:02] {2218} INFO - iteration 182, current learner extra_tree
# [flaml.automl.logger: 09-02 19:07:02] {2391} INFO -  at 49.0s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:02] {2218} INFO - iteration 183, current learner xgboost
# [flaml.automl.logger: 09-02 19:07:02] {2391} INFO -  at 49.1s,	estimator xgboost's best error=0.9301,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:02] {2218} INFO - iteration 184, current learner rf
# [flaml.automl.logger: 09-02 19:07:03] {2391} INFO -  at 50.0s,	estimator rf's best error=0.9107,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:03] {2218} INFO - iteration 185, current learner xgboost
# [flaml.automl.logger: 09-02 19:07:03] {2391} INFO -  at 50.1s,	estimator xgboost's best error=0.9301,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:03] {2218} INFO - iteration 186, current learner extra_tree
# [flaml.automl.logger: 09-02 19:07:03] {2391} INFO -  at 50.3s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:03] {2218} INFO - iteration 187, current learner xgboost
# [flaml.automl.logger: 09-02 19:07:03] {2391} INFO -  at 50.4s,	estimator xgboost's best error=0.9301,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:03] {2218} INFO - iteration 188, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:07:03] {2391} INFO -  at 50.4s,	estimator xgb_limitdepth's best error=0.9436,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:03] {2218} INFO - iteration 189, current learner rf
# [flaml.automl.logger: 09-02 19:07:04] {2391} INFO -  at 51.0s,	estimator rf's best error=0.9107,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:04] {2218} INFO - iteration 190, current learner xgboost
# [flaml.automl.logger: 09-02 19:07:04] {2391} INFO -  at 51.0s,	estimator xgboost's best error=0.9301,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:04] {2218} INFO - iteration 191, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:07:04] {2391} INFO -  at 51.1s,	estimator xgb_limitdepth's best error=0.9436,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:04] {2218} INFO - iteration 192, current learner xgboost
# [flaml.automl.logger: 09-02 19:07:04] {2391} INFO -  at 51.2s,	estimator xgboost's best error=0.9301,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:04] {2218} INFO - iteration 193, current learner extra_tree
# [flaml.automl.logger: 09-02 19:07:04] {2391} INFO -  at 51.4s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:04] {2218} INFO - iteration 194, current learner extra_tree
# [flaml.automl.logger: 09-02 19:07:05] {2391} INFO -  at 51.6s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:05] {2218} INFO - iteration 195, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:07:05] {2391} INFO -  at 51.7s,	estimator xgb_limitdepth's best error=0.9436,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:05] {2218} INFO - iteration 196, current learner xgboost
# [flaml.automl.logger: 09-02 19:07:05] {2391} INFO -  at 51.7s,	estimator xgboost's best error=0.9301,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:05] {2218} INFO - iteration 197, current learner rf
# [flaml.automl.logger: 09-02 19:07:05] {2391} INFO -  at 52.3s,	estimator rf's best error=0.9107,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:05] {2218} INFO - iteration 198, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:07:05] {2391} INFO -  at 52.4s,	estimator xgb_limitdepth's best error=0.9436,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:05] {2218} INFO - iteration 199, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:07:05] {2391} INFO -  at 52.4s,	estimator xgb_limitdepth's best error=0.9436,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:05] {2218} INFO - iteration 200, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:07:05] {2391} INFO -  at 52.5s,	estimator xgb_limitdepth's best error=0.9436,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:05] {2218} INFO - iteration 201, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:07:06] {2391} INFO -  at 52.5s,	estimator xgb_limitdepth's best error=0.9403,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:06] {2218} INFO - iteration 202, current learner lgbm
# [flaml.automl.logger: 09-02 19:07:06] {2391} INFO -  at 52.6s,	estimator lgbm's best error=0.9238,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:06] {2218} INFO - iteration 203, current learner xgboost
# [flaml.automl.logger: 09-02 19:07:06] {2391} INFO -  at 52.6s,	estimator xgboost's best error=0.9301,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:06] {2218} INFO - iteration 204, current learner extra_tree
# [flaml.automl.logger: 09-02 19:07:06] {2391} INFO -  at 52.9s,	estimator extra_tree's best error=0.9186,	best estimator rf's best error=0.9107
# [flaml.automl.logger: 09-02 19:07:06] {2218} INFO - iteration 205, current learner xgb_limitdepth
# ...
# [flaml.automl.logger: 09-02 19:07:43] {2218} INFO - iteration 362, current learner xgboost
# [flaml.automl.logger: 09-02 19:07:43] {2391} INFO -  at 89.9s,	estimator xgboost's best error=0.9213,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:43] {2218} INFO - iteration 363, current learner xgboost
# [flaml.automl.logger: 09-02 19:07:43] {2391} INFO -  at 89.9s,	estimator xgboost's best error=0.9213,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:43] {2218} INFO - iteration 364, current learner xgboost
# [flaml.automl.logger: 09-02 19:07:43] {2391} INFO -  at 90.0s,	estimator xgboost's best error=0.9213,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:43] {2218} INFO - iteration 365, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:07:43] {2391} INFO -  at 90.1s,	estimator xgb_limitdepth's best error=0.9303,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:43] {2218} INFO - iteration 366, current learner rf
# [flaml.automl.logger: 09-02 19:07:45] {2391} INFO -  at 91.6s,	estimator rf's best error=0.9103,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:45] {2218} INFO - iteration 367, current learner rf
# [flaml.automl.logger: 09-02 19:07:46] {2391} INFO -  at 92.5s,	estimator rf's best error=0.9103,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:46] {2218} INFO - iteration 368, current learner extra_tree
# [flaml.automl.logger: 09-02 19:07:46] {2391} INFO -  at 92.7s,	estimator extra_tree's best error=0.9179,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:46] {2218} INFO - iteration 369, current learner xgboost
# [flaml.automl.logger: 09-02 19:07:47] {2391} INFO -  at 94.3s,	estimator xgboost's best error=0.9213,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:47] {2218} INFO - iteration 370, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:07:48] {2391} INFO -  at 94.6s,	estimator xgb_limitdepth's best error=0.9303,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:48] {2218} INFO - iteration 371, current learner xgboost
# [flaml.automl.logger: 09-02 19:07:48] {2391} INFO -  at 94.8s,	estimator xgboost's best error=0.9213,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:48] {2218} INFO - iteration 372, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:07:48] {2391} INFO -  at 95.0s,	estimator xgb_limitdepth's best error=0.9286,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:48] {2218} INFO - iteration 373, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:07:48] {2391} INFO -  at 95.1s,	estimator xgb_limitdepth's best error=0.9286,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:48] {2218} INFO - iteration 374, current learner extra_tree
# [flaml.automl.logger: 09-02 19:07:48] {2391} INFO -  at 95.3s,	estimator extra_tree's best error=0.9179,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:48] {2218} INFO - iteration 375, current learner rf
# [flaml.automl.logger: 09-02 19:07:49] {2391} INFO -  at 96.1s,	estimator rf's best error=0.9103,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:49] {2218} INFO - iteration 376, current learner xgboost
# [flaml.automl.logger: 09-02 19:07:49] {2391} INFO -  at 96.2s,	estimator xgboost's best error=0.9213,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:49] {2218} INFO - iteration 377, current learner lgbm
# [flaml.automl.logger: 09-02 19:07:49] {2391} INFO -  at 96.2s,	estimator lgbm's best error=0.9238,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:49] {2218} INFO - iteration 378, current learner rf
# [flaml.automl.logger: 09-02 19:07:51] {2391} INFO -  at 97.9s,	estimator rf's best error=0.9103,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:51] {2218} INFO - iteration 379, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:07:51] {2391} INFO -  at 98.0s,	estimator xgb_limitdepth's best error=0.9286,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:51] {2218} INFO - iteration 380, current learner lgbm
# [flaml.automl.logger: 09-02 19:07:51] {2391} INFO -  at 98.1s,	estimator lgbm's best error=0.9238,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:51] {2218} INFO - iteration 381, current learner xgboost
# [flaml.automl.logger: 09-02 19:07:51] {2391} INFO -  at 98.1s,	estimator xgboost's best error=0.9213,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:51] {2218} INFO - iteration 382, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:07:51] {2391} INFO -  at 98.3s,	estimator xgb_limitdepth's best error=0.9286,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:51] {2218} INFO - iteration 383, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:07:51] {2391} INFO -  at 98.5s,	estimator xgb_limitdepth's best error=0.9286,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:51] {2218} INFO - iteration 384, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:07:52] {2391} INFO -  at 98.6s,	estimator xgb_limitdepth's best error=0.9286,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:52] {2218} INFO - iteration 385, current learner rf
# [flaml.automl.logger: 09-02 19:07:53] {2391} INFO -  at 99.9s,	estimator rf's best error=0.9103,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:53] {2218} INFO - iteration 386, current learner xgboost
# [flaml.automl.logger: 09-02 19:07:53] {2391} INFO -  at 100.0s,	estimator xgboost's best error=0.9213,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:53] {2218} INFO - iteration 387, current learner xgboost
# [flaml.automl.logger: 09-02 19:07:53] {2391} INFO -  at 100.0s,	estimator xgboost's best error=0.9213,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:53] {2218} INFO - iteration 388, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:07:53] {2391} INFO -  at 100.1s,	estimator xgb_limitdepth's best error=0.9286,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:53] {2218} INFO - iteration 389, current learner rf
# [flaml.automl.logger: 09-02 19:07:54] {2391} INFO -  at 101.2s,	estimator rf's best error=0.9103,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:54] {2218} INFO - iteration 390, current learner rf
# [flaml.automl.logger: 09-02 19:07:55] {2391} INFO -  at 102.4s,	estimator rf's best error=0.9103,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:55] {2218} INFO - iteration 391, current learner rf
# [flaml.automl.logger: 09-02 19:07:57] {2391} INFO -  at 103.6s,	estimator rf's best error=0.9103,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:57] {2218} INFO - iteration 392, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:07:57] {2391} INFO -  at 103.7s,	estimator xgb_limitdepth's best error=0.9286,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:57] {2218} INFO - iteration 393, current learner xgboost
# [flaml.automl.logger: 09-02 19:07:57] {2391} INFO -  at 103.8s,	estimator xgboost's best error=0.9213,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:57] {2218} INFO - iteration 394, current learner lgbm
# [flaml.automl.logger: 09-02 19:07:57] {2391} INFO -  at 103.9s,	estimator lgbm's best error=0.9238,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:57] {2218} INFO - iteration 395, current learner xgboost
# [flaml.automl.logger: 09-02 19:07:57] {2391} INFO -  at 103.9s,	estimator xgboost's best error=0.9213,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:57] {2218} INFO - iteration 396, current learner rf
# [flaml.automl.logger: 09-02 19:07:58] {2391} INFO -  at 105.0s,	estimator rf's best error=0.9103,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:07:58] {2218} INFO - iteration 397, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:08:00] {2391} INFO -  at 107.1s,	estimator xgb_limitdepth's best error=0.9286,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:08:00] {2218} INFO - iteration 398, current learner rf
# [flaml.automl.logger: 09-02 19:08:02] {2391} INFO -  at 108.6s,	estimator rf's best error=0.9103,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:08:02] {2218} INFO - iteration 399, current learner lgbm
# [flaml.automl.logger: 09-02 19:08:02] {2391} INFO -  at 108.6s,	estimator lgbm's best error=0.9238,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:08:02] {2218} INFO - iteration 400, current learner xgboost
# [flaml.automl.logger: 09-02 19:08:02] {2391} INFO -  at 108.7s,	estimator xgboost's best error=0.9213,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:08:02] {2218} INFO - iteration 401, current learner extra_tree
# [flaml.automl.logger: 09-02 19:08:02] {2391} INFO -  at 108.8s,	estimator extra_tree's best error=0.9179,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:08:02] {2218} INFO - iteration 402, current learner catboost
# [flaml.automl.logger: 09-02 19:08:02] {2391} INFO -  at 109.1s,	estimator catboost's best error=0.9307,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:08:02] {2218} INFO - iteration 403, current learner xgboost
# [flaml.automl.logger: 09-02 19:08:02] {2391} INFO -  at 109.1s,	estimator xgboost's best error=0.9213,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:08:02] {2218} INFO - iteration 404, current learner xgboost
# [flaml.automl.logger: 09-02 19:08:02] {2391} INFO -  at 109.2s,	estimator xgboost's best error=0.9213,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:08:02] {2218} INFO - iteration 405, current learner xgboost
# [flaml.automl.logger: 09-02 19:08:02] {2391} INFO -  at 109.2s,	estimator xgboost's best error=0.9213,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:08:02] {2218} INFO - iteration 406, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:08:02] {2391} INFO -  at 109.3s,	estimator xgb_limitdepth's best error=0.9286,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:08:02] {2218} INFO - iteration 407, current learner extra_tree
# [flaml.automl.logger: 09-02 19:08:03] {2391} INFO -  at 109.5s,	estimator extra_tree's best error=0.9179,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:08:03] {2218} INFO - iteration 408, current learner lgbm
# [flaml.automl.logger: 09-02 19:08:03] {2391} INFO -  at 109.6s,	estimator lgbm's best error=0.9238,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:08:03] {2218} INFO - iteration 409, current learner xgboost
# [flaml.automl.logger: 09-02 19:08:03] {2391} INFO -  at 109.7s,	estimator xgboost's best error=0.9213,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:08:03] {2218} INFO - iteration 410, current learner xgboost
# [flaml.automl.logger: 09-02 19:08:03] {2391} INFO -  at 109.7s,	estimator xgboost's best error=0.9213,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:08:03] {2218} INFO - iteration 411, current learner xgb_limitdepth
# [flaml.automl.logger: 09-02 19:08:03] {2391} INFO -  at 109.8s,	estimator xgb_limitdepth's best error=0.9286,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:08:03] {2218} INFO - iteration 412, current learner rf
# [flaml.automl.logger: 09-02 19:08:04] {2391} INFO -  at 110.8s,	estimator rf's best error=0.9103,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:08:04] {2218} INFO - iteration 413, current learner rf
# [flaml.automl.logger: 09-02 19:08:05] {2391} INFO -  at 111.8s,	estimator rf's best error=0.9103,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:08:05] {2218} INFO - iteration 414, current learner rf
# [flaml.automl.logger: 09-02 19:08:06] {2391} INFO -  at 112.7s,	estimator rf's best error=0.9103,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:08:06] {2218} INFO - iteration 415, current learner xgboost
# [flaml.automl.logger: 09-02 19:08:06] {2391} INFO -  at 112.7s,	estimator xgboost's best error=0.9213,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:08:06] {2218} INFO - iteration 416, current learner rf
# [flaml.automl.logger: 09-02 19:08:06] {2391} INFO -  at 113.5s,	estimator rf's best error=0.9103,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:08:07] {2218} INFO - iteration 417, current learner xgboost
# [flaml.automl.logger: 09-02 19:08:07] {2391} INFO -  at 113.5s,	estimator xgboost's best error=0.9213,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:08:07] {2218} INFO - iteration 418, current learner extra_tree
# [flaml.automl.logger: 09-02 19:08:07] {2391} INFO -  at 113.7s,	estimator extra_tree's best error=0.9179,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:08:07] {2218} INFO - iteration 419, current learner xgboost
# [flaml.automl.logger: 09-02 19:08:07] {2391} INFO -  at 113.8s,	estimator xgboost's best error=0.9213,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:08:07] {2218} INFO - iteration 420, current learner xgboost
# [flaml.automl.logger: 09-02 19:08:07] {2391} INFO -  at 113.9s,	estimator xgboost's best error=0.9213,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:08:07] {2218} INFO - iteration 421, current learner rf
# [flaml.automl.logger: 09-02 19:08:08] {2391} INFO -  at 115.0s,	estimator rf's best error=0.9103,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:08:08] {2218} INFO - iteration 422, current learner extra_tree
# [flaml.automl.logger: 09-02 19:08:09] {2391} INFO -  at 115.6s,	estimator extra_tree's best error=0.9179,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:08:09] {2218} INFO - iteration 423, current learner catboost
# [flaml.automl.logger: 09-02 19:08:10] {2391} INFO -  at 116.5s,	estimator catboost's best error=0.9307,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:08:10] {2218} INFO - iteration 424, current learner extra_tree
# [flaml.automl.logger: 09-02 19:08:10] {2391} INFO -  at 117.1s,	estimator extra_tree's best error=0.9179,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:08:10] {2218} INFO - iteration 425, current learner xgboost
# [flaml.automl.logger: 09-02 19:08:10] {2391} INFO -  at 117.3s,	estimator xgboost's best error=0.9213,	best estimator rf's best error=0.9103
# [flaml.automl.logger: 09-02 19:08:10] {2218} INFO - iteration 426, current learner rf
# [flaml.automl.logger: 09-02 19:08:11] {2391} INFO -  at 117.9s,	estimator rf's best error=0.9088,	best estimator rf's best error=0.9088
# [flaml.automl.logger: 09-02 19:08:11] {2218} INFO - iteration 427, current learner rf
# [flaml.automl.logger: 09-02 19:08:13] {2391} INFO -  at 120.3s,	estimator rf's best error=0.9088,	best estimator rf's best error=0.9088
# [flaml.automl.logger: 09-02 19:08:13] {2627} INFO - retrain rf for 0.1s
# [flaml.automl.logger: 09-02 19:08:13] {2630} INFO - retrained model: RandomForestRegressor(max_features=0.6648203842829868, max_leaf_nodes=18,
#                       n_estimators=27, n_jobs=-1, random_state=12032022)
# [flaml.automl.logger: 09-02 19:08:13] {1930} INFO - fit succeeded
# [flaml.automl.logger: 09-02 19:08:13] {1931} INFO - Time taken to find the best model: 117.92813611030579
# RandomForestRegressor(max_features=0.6648203842829868, max_leaf_nodes=18,
#                       n_estimators=27, n_jobs=-1, random_state=12032022)

# %%
mape =[]
mae =[]
y_pred = automl.predict(x_test)
for i in range(y_test.shape[0]):
  mae1 = abs(y_test[i]-y_pred[i])
  m = mae1 /y_test[i]
  mape.append(m)
  mae.append(mae1)
mape = np.asarray(mape)
mae = np.asarray(mae)
r2=r2_score(y_test,y_pred)
print(f'mg:{y_pred.mean()}, MAPE = {mape.mean()*100} МАЕ = {mae.mean()} R2 = {r2}')
print(f'Процент значений >0.5 {(mae > 0.5).sum()/mae.shape*100}%')
print(f'MAE quantile 75% {np.quantile(mae,0.75)}')
indexes = np.argsort(y_test)
plt.plot(y_test[indexes],mae[indexes], label = 'MAE')
plt.plot(r2, label = 'r2')
plt.show()
# Out:
# mg:0.28115425216389617, MAPE = 41.03482187214015 МАЕ = 0.09346813293009802 R2 = 0.09710304814331383
# Процент значений >0.5 [0.330033]%
# MAE quantile 75% 0.13480320122840628
